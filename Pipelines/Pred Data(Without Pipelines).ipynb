# %%
import pickle
import numpy as np

decision_tree_clasf = pickle.load(open('Decision_tree_classifier_model.pkl', 'rb'))
ohe_sex = pickle.load(open('ohe_sex.pkl', 'rb'))
ohe_embarked = pickle.load(open('ohe_embarked.pkl', 'rb'))

# %%
user_input = np.array([3, 'female',	6.04, 2,	31.2750,	'S']).reshape(1, 6)

# %%
user_input
# Out:
# array([['3', 'female', '6.04', '2', '31.275', 'S']], dtype='<U32')

# %%
user_input_sex = ohe_sex.transform(user_input[:, 1].reshape(1, 1))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
user_input_sex
# Out:
# array([[1., 0.]])

# %%
user_input_embarked = ohe_embarked.transform(user_input[:, 1].reshape(1, 1))

# %%
user_input_embarked
# Out:
# array([[0., 0., 0.]])

# %%
user_input_age = user_input[:,2].reshape(1,1)

# %%
user_input_transf = np.concatenate((user_input[:, [0,3,4]], user_input_age, user_input_sex, user_input_embarked), axis=1)

# %%
user_input_transf.shape
# Out:
# (1, 9)
