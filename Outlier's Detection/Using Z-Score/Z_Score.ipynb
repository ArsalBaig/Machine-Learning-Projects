# %% [markdown]
# # Loading DataSet & Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %% [markdown]
# # Plotting Graph.

# %%
fig = plt.figure(figsize= (10,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])
plt.show()
# Out:
# <ipython-input-54-f3b755673046>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# <ipython-input-54-f3b755673046>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
print("Min value: ", df['cgpa'].min())
print("Max value: ", df['cgpa'].max())
# Out:
# Min value:  4.89
# Max value:  9.12

# %% [markdown]
# # Getting Boundaries.

# %%
# Boundary Limit's

print("Highest Allowed: ", df['cgpa'].mean() + (3*df['cgpa'].std()))
print("Lowest Allowed: ", df['cgpa'].mean() - (3*df['cgpa'].std()))
# Out:
# Highest Allowed:  8.808933625397168
# Lowest Allowed:  5.113546374602832

# %% [markdown]
# # Find Outliers.

# %%
# Finding Outliers.

# Finding Outliers.

df = df[((df['cgpa']) > 8.00) | (df['cgpa'] < 5.50)]
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 78   8.20                  12.0       0
# 684  8.02                  67.0       0
# 263  8.11                  50.0       1
# 440  8.56                  22.0       0
# 275  8.03                  39.0       0

# %%
# Trimming.

new_df = df[((df['cgpa'] < 8.80) & (df['cgpa'] > 5.50))]
new_df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 279  8.49                  40.0       1
# 596  8.48                  25.0       1
# 614  8.05                  41.0       0
# 440  8.56                  22.0       0
# 407  8.23                  20.0       1

# %%
new_df.shape
# Out:
# (44, 3)

# %% [markdown]
# # Applying Z-Score.

# %%
df['cgpa_Zscore'] = (df['cgpa'] - df['cgpa'].mean()) / df['cgpa'].std()
df.head()
# Out:
# <ipython-input-60-5d3481086dc8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cgpa_Zscore'] = (df['cgpa'] - df['cgpa'].mean()) / df['cgpa'].std()
#     cgpa  placement_exam_marks  placed  cgpa_Zscore
# 34  8.15                   9.0       0     0.317466
# 37  8.51                   9.0       1     0.639236
# 49  8.23                  28.0       1     0.388970
# 54  8.42                  36.0       1     0.558793
# 55  8.12                  15.0       0     0.290652
